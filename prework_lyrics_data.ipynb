# %% [markdown]
# ## Einlesen unseres Datasets

# %%
import pandas as pd

# %%
hate_spotify_dataset = pd.read_csv("data/hate_spotify_songs.csv")

# %%
hate_spotify_dataset
# Out:
#       Unnamed: 0                                         track_name  \
# 0              0  Baby It's Cold Outside (feat. Christina Aguilera)
# 1              1                                            Changes
# 2              2                                               Laps
# 3              3                                                Hot
# 4              4                                          Love Sosa
# ...          ...                                                ...
# 1761        1761                                           Coastin'
# 1762        1762                                            I'm A G
# 1763        1763                                       Slutty Girls
# 1764        1764  Work REMIX (feat. A$AP Rocky, French Montana, ...
# 1765        1765             I'll Do 4 U (Re-Recorded / Remastered)
#
#          track_artist                                             lyrics  \
# 0         CeeLo Green  I really can't stay Baby it's cold outside I'v...
# ...

# %%
hate_spotify_dataset.lyrics
# Out:
# 0       I really can't stay Baby it's cold outside I'v...
# 1       I see no changes, wake up in the morning and I...
# 2       I'mma make your CXRPSE dance Ugh, hop in that ...
# 3       (Yeah) I'm the new truth, the crypto Erry'body...
# 4       Fuckers in school telling me, always in the ba...
#                               ...
# 1761    Mike G, why don't you drop us somethin' else? ...
# 1762    Uh I wear a gun like a girdle Bullet proof car...
# 1763    I was riding in my rola That's when I spotted ...
# 1764    I gotta close the window before I record ‘Caus...
# 1765    (Would you do for me) Sweetheart (Would you do...
# Name: lyrics, Length: 1766, dtype: object

# %% [markdown]
# ## Lyrics auteilen und in verschiedene Dateien schreiben, um sie zu annotieren

# %%
lyrics_data_1 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[0:50],
                              'interpret': hate_spotify_dataset.track_artist[0:50], 
                              'lyrics': hate_spotify_dataset.lyrics[0:50]})
lyrics_data_1_df = pd.DataFrame(lyrics_data_1)
lyrics_data_1_df.to_csv("lyrics_data/lyrics_to_annotate_1.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_2 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[50:100],
                              'interpret': hate_spotify_dataset.track_artist[50:10], 
                              'lyrics': hate_spotify_dataset.lyrics[50:100]})
lyrics_data_2_df = pd.DataFrame(lyrics_data_2)
lyrics_data_2_df.to_csv("lyrics_data/lyrics_to_annotate_2.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_3 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[100:150],
                              'interpret': hate_spotify_dataset.track_artist[100:150], 
                              'lyrics': hate_spotify_dataset.lyrics[100:150]})
lyrics_data_3_df = pd.DataFrame(lyrics_data_3)
lyrics_data_3_df.to_csv("lyrics_data/lyrics_to_annotate_3.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_4 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[150:200],
                              'interpret': hate_spotify_dataset.track_artist[150:200], 
                              'lyrics': hate_spotify_dataset.lyrics[150:200]})
lyrics_data_4_df = pd.DataFrame(lyrics_data_4)
lyrics_data_4_df.to_csv("lyrics_data/lyrics_to_annotate_4.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_5 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[200:250],
                              'interpret': hate_spotify_dataset.track_artist[200:250], 
                              'lyrics': hate_spotify_dataset.lyrics[200:250]})
lyrics_data_5_df = pd.DataFrame(lyrics_data_5)
lyrics_data_5_df.to_csv("lyrics_data/lyrics_to_annotate_5.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_6 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[250:300],
                              'interpret': hate_spotify_dataset.track_artist[250:300], 
                              'lyrics': hate_spotify_dataset.lyrics[250:300]})
lyrics_data_6_df = pd.DataFrame(lyrics_data_6)
lyrics_data_6_df.to_csv("lyrics_data/lyrics_to_annotate_6.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_7 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[300:350],
                              'interpret': hate_spotify_dataset.track_artist[300:350], 
                              'lyrics': hate_spotify_dataset.lyrics[300:350]})
lyrics_data_7_df = pd.DataFrame(lyrics_data_7)
lyrics_data_7_df.to_csv("lyrics_data/lyrics_to_annotate_7.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_8 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[350:400],
                              'interpret': hate_spotify_dataset.track_artist[350:400], 
                              'lyrics': hate_spotify_dataset.lyrics[350:400]})
lyrics_data_8_df = pd.DataFrame(lyrics_data_8)
lyrics_data_8_df.to_csv("lyrics_data/lyrics_to_annotate_8.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_9 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[400:450],
                              'interpret': hate_spotify_dataset.track_artist[400:450], 
                              'lyrics': hate_spotify_dataset.lyrics[400:450]})
lyrics_data_9_df = pd.DataFrame(lyrics_data_9)
lyrics_data_9_df.to_csv("lyrics_data/lyrics_to_annotate_9.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_10 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[450:500],
                               'interpret': hate_spotify_dataset.track_artist[450:500], 
                               'lyrics': hate_spotify_dataset.lyrics[450:500]})
lyrics_data_10_df = pd.DataFrame(lyrics_data_10)
lyrics_data_10_df.to_csv("lyrics_data/lyrics_to_annotate_10.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_11 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[500:550],
                               'interpret': hate_spotify_dataset.track_artist[500:550], 
                               'lyrics': hate_spotify_dataset.lyrics[500:550]})
lyrics_data_11_df = pd.DataFrame(lyrics_data_11)
lyrics_data_11_df.to_csv("lyrics_data/lyrics_to_annotate_11.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_12 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[550:600],
                               'interpret': hate_spotify_dataset.track_artist[550:600], 
                               'lyrics': hate_spotify_dataset.lyrics[550:600]})
lyrics_data_12_df = pd.DataFrame(lyrics_data_12)
lyrics_data_12_df.to_csv("lyrics_data/lyrics_to_annotate_12.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_13 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[600:650],
                               'interpret': hate_spotify_dataset.track_artist[600:650], 
                               'lyrics': hate_spotify_dataset.lyrics[600:650]})
lyrics_data_13_df = pd.DataFrame(lyrics_data_13)
lyrics_data_13_df.to_csv("lyrics_data/lyrics_to_annotate_13.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_14 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[650:700],
                               'interpret': hate_spotify_dataset.track_artist[650:700], 
                               'lyrics': hate_spotify_dataset.lyrics[650:700]})
lyrics_data_14_df = pd.DataFrame(lyrics_data_14)
lyrics_data_14_df.to_csv("lyrics_data/lyrics_to_annotate_14.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_15 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[700:750],
                               'interpret': hate_spotify_dataset.track_artist[700:750], 
                               'lyrics': hate_spotify_dataset.lyrics[700:750]})
lyrics_data_15_df = pd.DataFrame(lyrics_data_15)
lyrics_data_15_df.to_csv("lyrics_data/lyrics_to_annotate_15.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_16 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[750:800],
                               'interpret': hate_spotify_dataset.track_artist[750:800], 
                               'lyrics': hate_spotify_dataset.lyrics[750:800]})
lyrics_data_16_df = pd.DataFrame(lyrics_data_16)
lyrics_data_16_df.to_csv("lyrics_data/lyrics_to_annotate_16.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_17 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[800:850],
                               'interpret': hate_spotify_dataset.track_artist[800:850], 
                               'lyrics': hate_spotify_dataset.lyrics[800:850]})
lyrics_data_17_df = pd.DataFrame(lyrics_data_17)
lyrics_data_17_df.to_csv("lyrics_data/lyrics_to_annotate_17.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_18 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[850:900],
                               'interpret': hate_spotify_dataset.track_artist[850:900], 
                               'lyrics': hate_spotify_dataset.lyrics[850:900]})
lyrics_data_18_df = pd.DataFrame(lyrics_data_18)
lyrics_data_18_df.to_csv("lyrics_data/lyrics_to_annotate_18.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_19 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[900:950],
                               'interpret': hate_spotify_dataset.track_artist[900:950], 
                               'lyrics': hate_spotify_dataset.lyrics[900:950]})
lyrics_data_19_df = pd.DataFrame(lyrics_data_19)
lyrics_data_19_df.to_csv("lyrics_data/lyrics_to_annotate_19.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_20 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[950:1000],
                               'interpret': hate_spotify_dataset.track_artist[950:1000], 
                               'lyrics': hate_spotify_dataset.lyrics[950:1000]})
lyrics_data_20_df = pd.DataFrame(lyrics_data_20)
lyrics_data_20_df.to_csv("lyrics_data/lyrics_to_annotate_20.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_21 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[1000:1050],
                               'interpret': hate_spotify_dataset.track_artist[1000:1050], 
                               'lyrics': hate_spotify_dataset.lyrics[1000:1050]})
lyrics_data_21_df = pd.DataFrame(lyrics_data_21)
lyrics_data_21_df.to_csv("lyrics_data/lyrics_to_annotate_21.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_22 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[1050:1100],
                               'interpret': hate_spotify_dataset.track_artist[1050:1100], 
                               'lyrics': hate_spotify_dataset.lyrics[1050:1100]})
lyrics_data_22_df = pd.DataFrame(lyrics_data_22)
lyrics_data_22_df.to_csv("lyrics_data/lyrics_to_annotate_22.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_23 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[1100:1150],
                               'interpret': hate_spotify_dataset.track_artist[1100:1150], 
                               'lyrics': hate_spotify_dataset.lyrics[1100:1150]})
lyrics_data_23_df = pd.DataFrame(lyrics_data_23)
lyrics_data_23_df.to_csv("lyrics_data/lyrics_to_annotate_23.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_24 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[1150:1200],
                               'interpret': hate_spotify_dataset.track_artist[1150:1200], 
                               'lyrics': hate_spotify_dataset.lyrics[1150:1200]})
lyrics_data_24_df = pd.DataFrame(lyrics_data_24)
lyrics_data_24_df.to_csv("lyrics_data/lyrics_to_annotate_24.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_25 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[1200:1250],
                               'interpret': hate_spotify_dataset.track_artist[1200:1250], 
                               'lyrics': hate_spotify_dataset.lyrics[1200:1250]})
lyrics_data_25_df = pd.DataFrame(lyrics_data_25)
lyrics_data_25_df.to_csv("lyrics_data/lyrics_to_annotate_25.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_26 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[1250:1300],
                               'interpret': hate_spotify_dataset.track_artist[1250:1300], 
                               'lyrics': hate_spotify_dataset.lyrics[1250:1300]})
lyrics_data_26_df = pd.DataFrame(lyrics_data_26)
lyrics_data_26_df.to_csv("lyrics_data/lyrics_to_annotate_26.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_27 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[1300:1350],
                               'interpret': hate_spotify_dataset.track_artist[1300:1350], 
                               'lyrics': hate_spotify_dataset.lyrics[1300:1350]})
lyrics_data_27_df = pd.DataFrame(lyrics_data_27)
lyrics_data_27_df.to_csv("lyrics_data/lyrics_to_annotate_27.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_28 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[1350:1400],
                               'interpret': hate_spotify_dataset.track_artist[1350:1400], 
                               'lyrics': hate_spotify_dataset.lyrics[1350:1400]})
lyrics_data_28_df = pd.DataFrame(lyrics_data_28)
lyrics_data_28_df.to_csv("lyrics_data/lyrics_to_annotate_28.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_29 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[1400:1450],
                               'interpret': hate_spotify_dataset.track_artist[1400:1450], 
                               'lyrics': hate_spotify_dataset.lyrics[1400:1450]})
lyrics_data_29_df = pd.DataFrame(lyrics_data_29)
lyrics_data_29_df.to_csv("lyrics_data/lyrics_to_annotate_29.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_30 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[1450:1500],
                               'interpret': hate_spotify_dataset.track_artist[1450:1500], 
                               'lyrics': hate_spotify_dataset.lyrics[1450:1500]})
lyrics_data_30_df = pd.DataFrame(lyrics_data_30)
lyrics_data_30_df.to_csv("lyrics_data/lyrics_to_annotate_30.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_31 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[1500:1550],
                               'interpret': hate_spotify_dataset.track_artist[1500:1550], 
                               'lyrics': hate_spotify_dataset.lyrics[1500:1550]})
lyrics_data_31_df = pd.DataFrame(lyrics_data_31)
lyrics_data_31_df.to_csv("lyrics_data/lyrics_to_annotate_31.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_32 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[1550:1600],
                               'interpret': hate_spotify_dataset.track_artist[1550:1600], 
                               'lyrics': hate_spotify_dataset.lyrics[1550:1600]})
lyrics_data_32_df = pd.DataFrame(lyrics_data_32)
lyrics_data_32_df.to_csv("lyrics_data/lyrics_to_annotate_32.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_33 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[1600:1650],
                               'interpret': hate_spotify_dataset.track_artist[1600:1650], 
                               'lyrics': hate_spotify_dataset.lyrics[1600:1650]})
lyrics_data_33_df = pd.DataFrame(lyrics_data_33)
lyrics_data_33_df.to_csv("lyrics_data/lyrics_to_annotate_33.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_34 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[1650:1700],
                               'interpret': hate_spotify_dataset.track_artist[1650:1700], 
                               'lyrics': hate_spotify_dataset.lyrics[1650:1700]})
lyrics_data_34_df = pd.DataFrame(lyrics_data_34)
lyrics_data_34_df.to_csv("lyrics_data/lyrics_to_annotate_34.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_35 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[1700:1750],
                               'interpret': hate_spotify_dataset.track_artist[1700:1750], 
                               'lyrics': hate_spotify_dataset.lyrics[1700:1750]})
lyrics_data_35_df = pd.DataFrame(lyrics_data_35)
lyrics_data_35_df.to_csv("lyrics_data/lyrics_to_annotate_35.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_36 = pd.DataFrame({'songtitle': hate_spotify_dataset.track_name[1750:1766],
                               'interpret': hate_spotify_dataset.track_artist[1750:1766], 
                               'lyrics': hate_spotify_dataset.lyrics[1750:1766]})
lyrics_data_36_df = pd.DataFrame(lyrics_data_36)
lyrics_data_36_df.to_csv("lyrics_data/lyrics_to_annotate_36.csv", sep="\t", line_terminator='\n\n')

# %%
lyrics_data_24
# Out:
#                                             songtitle  \
# 1150                                         Highlife
# 1151                                            Crazy
# 1152                                           Schism
# 1153     Little Bad Girl (feat. Taio Cruz & Ludacris)
# 1154                                           Giddem
# 1155                                        Swan Song
# 1156                            Bitter Sweet Symphony
# 1157     Another One Bites The Dust - Remastered 2011
# 1158                              Legend of the South
# 1159                                       Boy Oh Boy
# 1160                                            Swish
# 1161                                       Time Taker
# 1162                              Killing In The Name
# 1163                                       Killin' Me
# 1164                                    Decatur Psalm
# 1165                                           Blocka
# ...
